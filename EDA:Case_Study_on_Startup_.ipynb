# %% [markdown]
# <a href="https://colab.research.google.com/github/Yousufalipangat/Git_ChatApp/blob/main/EDA%3ACase_Study_on_Startup_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Exploratory Data Analysis: Startup Dataset**

# %% [markdown]
# **Feature Details :**
#
# **SNo**- Serial number.
#
# **Date**- Date of funding in format DD/MM/YYYY.
#
# **StartupName**- Name of the startup which got funded.
#
# **IndustryVertical** - Industry to which the startup belongs.
#
# **SubVertical** - Sub-category of the industry type.
#
# **CityLocation** - City which the startup is based out of.
#
# **InvestorsName** - Name of the investors involved in the funding round.
#
# **InvestmentType** - Either Private Equity or Seed Funding.
#
# **AmountInUSD** - Funding Amount in USD.
#
# **Remarks** - Other information, if any.

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading Dataset

# %%
df = pd.read_csv("startup_funding.csv", index_col = 'Sr No')
display(df.head(10))
display(df.tail(5))
# Out:
#       Date dd/mm/yyyy                  Startup Name    Industry Vertical  \
# Sr No
# 1          09/01/2020                        BYJU’S               E-Tech
# 2          13/01/2020                        Shuttl       Transportation
# 3          09/01/2020                     Mamaearth           E-commerce
# 4          02/01/2020  https://www.wealthbucket.in/              FinTech
# 5          02/01/2020                        Fashor  Fashion and Apparel
# 6          13/01/2020                         Pando            Logistics
# 7          10/01/2020                        Zomato          Hospitality
# 8          12/12/2019                        Ecozen           Technology
# 9          06/12/2019                      CarDekho           E-Commerce
# 10         03/12/2019                  Dhruva Space            Aerospace
#
#                                     SubVertical City  Location  \
# Sr No
# 1                                    E-learning      Bengaluru
# 2                     App based shuttle service        Gurgaon
# 3         Retailer of baby and toddler products      Bengaluru
# 4                             Online Investment      New Delhi
# 5                   Embroiled Clothes For Women         Mumbai
# 6      Open-market, freight management platform        Chennai
# 7                 Online Food Delivery Platform        Gurgaon
# 8                                      Agritech           Pune
# 9                                    Automobile        Gurgaon
# 10                      Satellite Communication      Bengaluru
#
#                        Investors Name       InvestmentnType Amount in USD  \
# Sr No
# 1             Tiger Global Management  Private Equity Round  20,00,00,000
# 2           Susquehanna Growth Equity              Series C     80,48,394
# 3               Sequoia Capital India              Series B   1,83,58,860
# 4                      Vinod Khatumal          Pre-series A     30,00,000
# 5             Sprout Venture Partners            Seed Round     18,00,000
# 6                   Chiratae Ventures              Series A     90,00,000
# 7                       Ant Financial  Private Equity Round  15,00,00,000
# 8         Sathguru Catalyzer Advisors              Series A     60,00,000
# 9         Ping An Global Voyager Fund              Series D   7,00,00,000
# 10     Mumbai Angels, Ravikanth Reddy                  Seed   5,00,00,000
#
#       Remarks
# Sr No
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
#       Date dd/mm/yyyy      Startup Name Industry Vertical SubVertical  \
# Sr No
# 3040       29/01/2015        Printvenue               NaN         NaN
# 3041       29/01/2015          Graphene               NaN         NaN
# 3042       30/01/2015    Mad Street Den               NaN         NaN
# 3043       30/01/2015         Simplotel               NaN         NaN
# 3044       31/01/2015  couponmachine.in               NaN         NaN
#
#       City  Location                     Investors Name InvestmentnType  \
# Sr No
# 3040             NaN        Asia Pacific Internet Group  Private Equity
# 3041             NaN                     KARSEMVEN Fund  Private Equity
# 3042             NaN     Exfinity Fund, GrowX Ventures.  Private Equity
# 3043             NaN                         MakeMyTrip  Private Equity
# 3044             NaN  UK based Group of Angel Investors    Seed Funding
#
#       Amount in USD                            Remarks
# Sr No
# 3040      45,00,000                                NaN
# 3041       8,25,000                Govt backed VC Fund
# 3042      15,00,000                                NaN
# 3043            NaN  Strategic Funding, Minority stake
# 3044       1,40,000                                NaN

# %%
df[df["Startup Name"].isin(["boibanit", "oibanit"])]
# Out:
#       Date dd/mm/yyyy Startup Name                 Industry Vertical  \
# Sr No
# 2203       03/11/2015      oibanit  Online Food Ordering Marketplace
#
#       SubVertical City  Location              Investors Name InvestmentnType  \
# Sr No
# 2203          NaN       Vadodara  Varun Ahuja, Anubhav Verma    Seed Funding
#
#       Amount in USD Remarks
# Sr No
# 2203       1,50,000     NaN

# %% [markdown]
# # Data Cleansing and Manuipulations

# %%
# finding Datatypes and missings values in each columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3044 entries, 1 to 3044
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date dd/mm/yyyy    3044 non-null   object
#  1   Startup Name       3044 non-null   object
#  2   Industry Vertical  2873 non-null   object
#  3   SubVertical        2108 non-null   object
#  4   City  Location     2864 non-null   object
#  5   Investors Name     3020 non-null   object
#  6   InvestmentnType    3040 non-null   object
#  7   Amount in USD      2084 non-null   object
#  8   Remarks            419 non-null    object
# dtypes: object(9)
# memory usage: 237.8+ KB

# %%
df = df.drop(columns="Remarks")

# change the column name 'Date dd/mm/yyyy' tp 'Date' & InvestmentnType
df = df.rename(columns={"Date dd/mm/yyyy":"Date","InvestmentnType":"Investment Type"})

# %%
# find number of unique values of each columns
for column in df.columns:
  print(column,':',df[column].nunique())
# Out:
# Date : 1035
# Startup Name : 2459
# Industry Vertical : 821
# SubVertical : 1942
# City  Location : 112
# Investors Name : 2412
# Investment Type : 55
# Amount in USD : 471

# %%
#converting Date columns datatype to datetime
def to_datetime(date):
  try:
    return pd.to_datetime(date,format='%d/%m/%Y')
  except Exception as e:
    print(e)
    return date

df.Date = df.Date.apply(to_datetime)

print('Date type is',df.Date.dtype)
# Out:
# time data '05/072018' does not match format '%d/%m/%Y' (match)
# time data '01/07/015' does not match format '%d/%m/%Y' (match)
# time data '\\xc2\\xa010/7/2015' does not match format '%d/%m/%Y' (match)
# time data '12/05.2015' does not match format '%d/%m/%Y' (match)
# time data '12/05.2015' does not match format '%d/%m/%Y' (match)
# time data '13/04.2015' does not match format '%d/%m/%Y' (match)
# time data '15/01.2015' does not match format '%d/%m/%Y' (match)
# time data '22/01//2015' does not match format '%d/%m/%Y' (match)
# Date type is object

# %%
# time data '05/072018' is causing issue while parsing, so changing the value
df.Date = df.Date.replace(
{"05/072018":pd.to_datetime('05/07/2018',format='%d/%m/%Y'),
 "01/07/015":pd.to_datetime('01/07/2015',format='%d/%m/%Y'),
 "12/05.2015":pd.to_datetime('12/05/2015',format='%d/%m/%Y'),
 "13/04.2015":pd.to_datetime('13/04/2015',format='%d/%m/%Y'),
 "15/01.2015":pd.to_datetime('15/01/2015',format='%d/%m/%Y'),
 "22/01//2015":pd.to_datetime('22/01/2015',format='%d/%m/%Y'),
 r"\\xc2\\xa010/7/2015":pd.to_datetime('10/07/2015',format='%d/%m/%Y'),

 } )
print('Date type is',df.Date.dtype)
# Out:
# Date type is datetime64[ns]

# %% [markdown]
# # Column: 'Start Up'

# %%
df2 = df.copy()
print('Number of unique Values',df2['Startup Name'].nunique())
df2['Startup Name'] = df2['Startup Name'].str.lower().str.strip()
print('Number of unique Values after changing to lowercase and trimming',df2['Startup Name'].str.lower().str.strip().nunique())
print("Total number of null values",df2["Startup Name"].isnull().sum())
print("\n")
# Out:
# Number of unique Values 2459
# Number of unique Values after changing to lowercase and trimming 2349
# Total number of null values 0

# %%
#created a DF two understand the columns values
value_count_df = df2['Startup Name'].str.lower().str.strip().value_counts().reset_index().rename(columns={"index":"Startup Name", "Startup Name":"Value counts"})
display(value_count_df)
# Out:
#           Startup Name  Value counts
# 0               swiggy             8
# 1             ola cabs             8
# 2                paytm             7
# 3               meesho             6
# 4            blackbuck             6
# ...                ...           ...
# 2344       airmed labs             1
# 2345           99games             1
# 2346      loyaltyprime             1
# 2347        rml agtech             1
# 2348  couponmachine.in             1
#
# [2349 rows x 2 columns]

# %%
#created two new columns to understand how many similar startup names are there the dataset. This is to maily correct the startup name if it is
#represented in two names
value_count_df["Contain_in"] = value_count_df['Startup Name'].apply(lambda x: (sum(value_count_df['Startup Name'].str.contains(rf"{x}"))))
value_count_df["Similar_words"] = value_count_df['Startup Name'].apply(lambda x: value_count_df[value_count_df["Startup Name"].str.contains(rf"{x}")]["Startup Name"].tolist())
# Out:
# <ipython-input-82-8679e8ff9990>:3: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   value_count_df["Contain_in"] = value_count_df['Startup Name'].apply(lambda x: (sum(value_count_df['Startup Name'].str.contains(rf"{x}"))))
# <ipython-input-82-8679e8ff9990>:4: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   value_count_df["Similar_words"] = value_count_df['Startup Name'].apply(lambda x: value_count_df[value_count_df["Startup Name"].str.contains(rf"{x}")]["Startup Name"].tolist())

# %%
#changed the dipslay rowsize to 500
pd.set_option('display.max_rows', 500)

#filtering records whose startup name is simalar to more than 2 other startup names in dataset
value_count_df = value_count_df[value_count_df["Contain_in"] >1].sort_values("Contain_in")
display(value_count_df)

#let's understand the shape
value_count_df.shape
# Out:
#             Startup Name  Value counts  Contain_in  \
# 2                  paytm             7           2
# 1540              fitraq             1           2
# 1456              portea             1           2
# 1443            inshorts             1           2
# 1442          vahdam tea             1           2
# 1400             gurukul             1           2
# 1330           grabhouse             1           2
# 1320       caravan craft             1           2
# 1313             naaptol             1           2
# 1289                frsh             1           2
# 1223               whoop             1           2
# 1201       customfurnish             1           2
# 1177            bluegape             1           2
# 1171                didi             1           2
# 1163            absentia             1           2
# 1143           pressplay             1           2
# 1141  black white orange             1           2
# 1132             oibanit             1           2
# 1091              etaout             1           2
# 1024              ampere             1           2
# 938                istar             1           2
# 917            mydentist             1           2
# 913                elong             1           2
# 2267                volt             1           2
# 1546              dhruva             1           2
# 1591            arcatron             1           2
# 1648            zippserv             1           2
# 1680     vogo automotive             1           2
# 2266                vymo             1           2
# 2146                fyle             1           2
# 2102               genie             1           2
# 2098               runnr             1           2
# 2097                zolo             1           2
# 2086           neogrowth             1           2
# 2066                hike             1           2
# 2053            notesgen             1           2
# 1996           bluestone             1           2
# 1982            atomberg             1           2
# 1899                zeta             1           2
# 867             transerv             1           2
# 1897          healthkart             1           2
# 1866             nearbuy             1           2
# 1842             hwell24             1           2
# 1817            entropik             1           2
# 1786               gaana             1           2
# 1783         earlysalary             1           2
# 1778           samunnati             1           2
# 1763             peesafe             1           2
# 1731           capillary             1           2
# 1722               atlan             1           2
# 1694               pando             1           2
# 1691              incred             1           2
# 1885             cyclops             1           2
# 853                vahan             1           2
# 878               oyofit             1           2
# 302               zenify             2           2
# 356            active.ai             2           2
# 342            hansel.io             2           2
# 316                aisle             2           2
# 310             cartrade             2           2
# 55              cardekho             4           2
# 793                aahaa             1           2
# 278               teabox             2           2
# 269            satvacart             2           2
# 236               gympik             2           2
# 365             firstcry             2           2
# 60            healthians             4           2
# 195                cashe             2           2
# 84                roposo             3           2
# 85                 credr             3           2
# 187              purplle             2           2
# 186          springboard             2           2
# 172    little black book             2           2
# 171                 zefo             2           2
# 140               opinio             2           2
# 131             faircent             3           2
# 199           bigstylist             2           2
# 122                droom             3           2
# 50                  fynd             4           2
# 48                wooplr             4           2
# 787                reach             1           2
# 775                 yana             1           2
# 736                  byg             1           2
# 5              urbanclap             6           2
# 638               silvan             1           2
# 12              lenskart             6           2
# 590                  qyk             1           2
# 587              rentomo             1           2
# 581             cashkaro             1           2
# 392              netmeds             2           2
# 576        groupon india             1           2
# 13              flipkart             5           2
# 527             weddingz             1           2
# 519      veritas finance             1           2
# 490                tring             1           2
# 41                   1mg             4           2
# 428           smartivity             2           2
# 419                popxo             2           2
# 399          instalively             2           2
# 540                 leaf             1           2
# 119               rapido             3           2
# 17                 toppr             5           3
# 2328                 thb             1           3
# 1588               ambee             1           3
# 1391                vogo             1           3
# 539                bhive             1           3
# 2069                cult             1           4
# 685              housing             1           4
# 1740             healthi             1           5
# 227                 grab             2           5
# 636               little             1           5
# 1752          healthcare             1           5
# 848                  oyo             1           5
# 447                digit             2           6
# 467                buddy             1           7
# 42                   ola             4          12
# 1418                 era             1          19
#
#                                           Similar_words
# 2                            [paytm, paytm marketplace]
# 1540                               [fitraq.com, fitraq]
# 1456                           [portea medical, portea]
# 1443                           [newsinshorts, inshorts]
# 1442                          [vahdam tea, vahdam teas]
# 1400         [gurukul, creator\\xe2\\x80\\x99s gurukul]
# 1330                         [grabhouse.com, grabhouse]
# 1320              [caravan craft retail, caravan craft]
# 1313                             [naaptol.com, naaptol]
# 1289                                 [frsh.co.in, frsh]
# 1223                                [scoopwhoop, whoop]
# 1201                 [customfurnish.com, customfurnish]
# 1177                           [bluegape.com, bluegape]
# 1171                                     [didi, mydidi]
# 1163                            [absentia, absentia vr]
# 1143                          [pressplay, pressplay tv]
# 1141    [black white orange brands, black white orange]
# 1132                                [boibanit, oibanit]
# 1091                                  [betaout, etaout]
# 1024                          [ampere, ampere vehicles]
# 938                    [istar, istar skill development]
# 917                        [mydentistchoice, mydentist]
# 913                                     [elong, belong]
# 2267                               [volta motors, volt]
# 1546                             [dhruva, dhruva space]
# 1591                      [arcatron mobility, arcatron]
# 1648                              [zippserve, zippserv]
# 1680       [vogo automotive, vogo automotive pvt. ltd.]
# 2266                                   [savvymob, vymo]
# 2146                          [fyle technologies, fyle]
# 2102                                [yatragenie, genie]
# 2098                                 [roadrunnr, runnr]
# 2097                                  [zolo, zolostays]
# 2086                      [neogrowth credit, neogrowth]
# 2066                             [hike messenger, hike]
# 2053                     [\\xc2\\xa0notesgen, notesgen]
# 1996                   [\\xc2\\xa0bluestone, bluestone]
# 1982                    [atomberg technology, atomberg]
# 1899                                     [ezetap, zeta]
# 867                               [transerv, transerve]
# 1897                 g (healthkartplus), healthkart]
# 1866  [nearbuy (previously\\xc2\\xa0 groupon india),...
# 1842                            [hwell24 plus, hwell24]
# 1817                              [entropik, entropika]
# 1786                                 [gaana.com, gaana]
# 1783                     [earlysalary.com, earlysalary]
# 1778  [samunnati financial intermediation & services...
# 1763                              [peesafe.in, peesafe]
# 1731                        [capillary tech, capillary]
# 1722                             [caratlane.com, atlan]
# 1694                     [pando, pandorum technologies]
# 1691                           [incred finance, incred]
# 1885                          [cyclopsmedtech, cyclops]
# 853                               [vahanalytics, vahan]
# 878                                  [oyofit, froyofit]
# 302                                 [zenify, zenify.in]
# 356                              [active.ai, active ai]
# 342                              [hansel.io, hansel io]
# 316                                   [aisle, aisle.co]
# 310                            [cartrade, cartrade.com]
# 55                             [cardekho, cardekho.com]
# 793                               [aahaa, aahaa stores]
# 278                                [teabox, teabox.com]
# 269                    [satvacart, \\xc2\\xa0satvacart]
# 236                                [gympik, gympik.com]
# 365                            [firstcry, firstcry.com]
# 60                         [healthians, healthians.com]
# 195                                   [cashe, encashea]
# 84                                 [roposo, roposo.com]
# 85                                   [credr, credright]
# 187                              [purplle, purplle.com]
# 186                        [springboard, 91springboard]
# 172        [little black book, little black book delhi]
# 171                                      [zefo, gozefo]
# 140                              [opinio, grandopinion]
# 131                            [faircent, faircent.com]
# 199                        [bigstylist, bigstylist.com]
# 122                                   [droom, droom.in]
# 50                                       [fynd, gofynd]
# 48                                 [wooplr, wooplr.com]
# 787                                   [letreach, reach]
# 775                                      [yana, vayana]
# 736                                     [babygogo, byg]
# 5          [urbanclap, urbanclap technologies pvt. ltd]
# 638                    [silvan, silvan innovation labs]
# 12                             [lenskart, lenskart.com]
# 590                                      [qyk, qyk app]
# 587                                [rentomojo, rentomo]
# 581                            [cashkaro, cashkaro.com]
# 392                              [netmeds, netmeds.com]
# 576   [groupon india, nearbuy (previously\\xc2\\xa0 ...
# 13                             [flipkart, flipkart.com]
# 527                             [weddingz.in, weddingz]
# 519             [veritas finance, veritas finance ltd.]
# 490                                  [tring, adstringo]
# 41                          g, 1mg (healthkartplus)]
# 428                         [smartivity, smartivity.in]
# 419                                  [popxo, popxo.com]
# 399                      [instalively, instalively.com]
# 540                              [leaf, leaf wearables]
# 119                          [rapido, rapido bike taxi]
# 17                    [toppr, toppr.com, kidsstoppress]
# 2328    [healthbuds, https://www.wealthbucket.in/, thb]
# 1588                         [mosambee, ambee, roambee]
# 1391  [vogo, vogo automotive, vogo automotive pvt. l...
# 539            [bhive, bhiveworkspace, bhive workspace]
# 2069  [cult fitness, culture machine, culturealley, ...
# 685    [housing.com, housing, tata housing, housingman]
# 1740  [healthifyme, healthians, healthians.com, heal...
# 227   [grab, grabhouse.com, grabhouse, grabonrent, g...
# 636   [little black book, little, zovi.com / little ...
# 1752  [karma healthcare, soothe healthcare, my healt...
# 848        [oyo rooms, oyorooms, oyo, oyofit, froyofit]
# 447   [digit, digital gorkha, ping digital, focus di...
# 467   [buddy, sportobuddy, buddy4studdy, pregbuddy, ...
# 42    [ola cabs, holachef, ola, solartown, applied s...
# 1418  [canvera, leverage edu, meradoctor, kuvera, b9...
# (117, 4)

# %%
# we can see that some of the startup name as repeated as it's site name like .com,.in , .co.in , pvt. etc
# let's replace values for the same
for startup_name in value_count_df["Startup Name"]:

  #checking over the prefix
  df2["Startup Name"].replace(rf"^{startup_name}(\.com|\.in|\.co\.in|\spvt\.\sltd.|\sltd.|.co)$",startup_name,regex=True,inplace=True)

  #found some startup names are sepeated with space instead of '.'
  if "." in startup_name:
    first,last = startup_name.split(".")
    df2["Startup Name"].replace(rf"^{first}\s{last}$",startup_name,regex=True,inplace=True)

  #checking over the suffix
  df2["Startup Name"].replace(rf"^(\\\\xc2\\\\xa0){startup_name}$",startup_name,regex=True,inplace=True)

# %%
#names from site like sentense
df2["Startup Name"] = df2["Startup Name"].str.replace(r'https://www\.([a-zA-Z0-9_]+)\.in\S',r"\1",regex = True)

# %%
#unwanted character removals
df2["Startup Name"] = df2["Startup Name"].str.replace(r"\\\\xc2\\\\xa0","")
df2["Startup Name"] = df2["Startup Name"].str.replace(r"\\\\xe2\\\\x80\\\\x99","'")
df2["Startup Name"] = df2["Startup Name"].str.replace(r"\\xe2\\x80\\x99","'")
# Out:
# <ipython-input-86-f1cf3fa88e99>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df2["Startup Name"] = df2["Startup Name"].str.replace(r"\\\\xc2\\\\xa0","")
# <ipython-input-86-f1cf3fa88e99>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df2["Startup Name"] = df2["Startup Name"].str.replace(r"\\\\xe2\\\\x80\\\\x99","'")
# <ipython-input-86-f1cf3fa88e99>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df2["Startup Name"] = df2["Startup Name"].str.replace(r"\\xe2\\x80\\x99","'")

# %%
# spelling mistake and duplicates correction
df2["Startup Name"] = df2["Startup Name"].replace({
    "urbanclap technologies pvt. ltd":"urbanclap",
     "elong":"belong",
     "ampere":"ampere vehicles",
     "aahaa":"aahaa stores",
     "bhiveworkspace":"bhive",
     "bhive workspace":"bhive",
     "cult":"cult fitness",
     "oyorooms":"oyo",
     "oyo rooms":"oyo",
     "olacabs":"ola",
     "ola cabs":"ola",
     "ola electric":"ola" ,
     "\"byju\\\\\'s\"":"byju\'s",
     "paytm marketplace":"paytm",
     "absentia vr":"absentia",
    "oibanit":"boibanit",
     "etaout":"betaout",
     'hike messenger':"hike",
    "vahdam tea":"vahdam teas",
    "atomberg":"atomberg technology",
    "zippserv":"zippserve",
    "incred finance": "incred",
    "capillary":"capillary tech"

})

# %% [markdown]
# # Column: 'Industry Vertical'

# %%
print('Number of unique Values',df2['Industry Vertical'].nunique())
df2['Industry Vertical'] = df2['Industry Vertical'].str.lower().str.strip()
print('Number of unique Values after changing to lowercase and trimming',df2['Industry Vertical'].str.lower().str.strip().nunique())
print("Total number of null values",df2["Industry Vertical"].isnull().sum())
print("\n")
df2["Industry Vertical"]
# Out:
# Number of unique Values 821
# Number of unique Values after changing to lowercase and trimming 799
# Total number of null values 171
# Sr No
# 1                    e-tech
# 2            transportation
# 3                e-commerce
# 4                   fintech
# 5       fashion and apparel
#                ...
# 3040                    NaN
# 3041                    NaN
# 3042                    NaN
# 3043                    NaN
# 3044                    NaN
# Name: Industry Vertical, Length: 3044, dtype: object

# %%
df3 = df2.copy()


# df3[df3["Industry Vertical"].str.contains("\\\\",na=False)]

# removed special characters or Unicode characters
df3["Industry Vertical"] = df3["Industry Vertical"].str.replace(r"\\\\x[a-f0-9]{2}",r"",regex=True)
df3["Industry Vertical"] = df3["Industry Vertical"].str.replace(r"\\x[a-f0-9]{2}",r"",regex=True)
df3["Industry Vertical"] = df3["Industry Vertical"].str.replace(r"\\\\n",r" ",regex=True)

# %%
# # we have grouped based on startup name and later forward filled industry Verticals
df3["Industry Vertical"] = df3[['Startup Name','Industry Vertical']].sort_values(['Startup Name','Industry Vertical'],ascending=False).groupby("Startup Name").ffill()
# display(df3[df3['Startup Name'].str.contains("cardekho")])

print("Total number of null values",df3["Industry Vertical"].isnull().sum())
#we have reduced many null values here
# Out:
# Total number of null values 104

# %% [markdown]
# # Column: 'SubVertical'

# %%
column = 'SubVertical'
print('Number of unique Values',df3[column].nunique())
df3[column] = df3[column].str.lower().str.strip()
print('Number of unique Values after changing to lowercase and trimming',df3[column].nunique())
print("Total number of null values",df3[column].isnull().sum())
print("\n")
df3[column]
# Out:
# Number of unique Values 1942
# Number of unique Values after changing to lowercase and trimming 1883
# Total number of null values 936
# Sr No
# 1                                  e-learning
# 2                   app based shuttle service
# 3       retailer of baby and toddler products
# 4                           online investment
# 5                 embroiled clothes for women
#                         ...
# 3040                                      NaN
# 3041                                      NaN
# 3042                                      NaN
# 3043                                      NaN
# 3044                                      NaN
# Name: SubVertical, Length: 3044, dtype: object

# %%
# removed special characters or Unicode characters
df3["SubVertical"] = df3["SubVertical"].str.replace(r"\\\\x[a-f0-9]{2}",r"",regex=True)
df3["SubVertical"] = df3["SubVertical"].str.replace(r"\\x[a-f0-9]{2}",r"",regex=True)
df3["SubVertical"] = df3["SubVertical"].str.replace(r"\\\\n",r" ",regex=True)

#we have grouped based on startup name and later forward filled subverticals
df3["SubVertical"] = df3[['Startup Name','SubVertical']].sort_values(['Startup Name','SubVertical'],ascending=False).groupby("Startup Name").ffill()

# %%
print("Total number of null values",df3["SubVertical"].isnull().sum())
# Out:
# Total number of null values 636

# %%
df3['SubVertical'].fillna("Unknown",inplace = True)

# %% [markdown]
# # Column: 'City  Location'

# %%
column = 'City  Location'
print('Number of unique Values',df3[column].nunique())
df3[column] = df3[column].str.lower().str.strip()
print('Number of unique Values after changing to lowercase and trimming',df3[column].nunique())
print("Total number of null values",df3[column].isnull().sum())
print("\n")
df3[column]
# Out:
# Number of unique Values 112
# Number of unique Values after changing to lowercase and trimming 112
# Total number of null values 180
# Sr No
# 1       bengaluru
# 2         gurgaon
# 3       bengaluru
# 4       new delhi
# 5          mumbai
#           ...
# 3040          NaN
# 3041          NaN
# 3042          NaN
# 3043          NaN
# 3044          NaN
# Name: City  Location, Length: 3044, dtype: object

# %%
column = 'City  Location'
# removed special characters or Unicode characters
df3[column] = df3[column].str.replace(r"\\\\x[a-f0-9]{2}",r"",regex=True)
df3[column] = df3[column].str.replace(r"\\x[a-f0-9]{2}",r"",regex=True)
df3[column] = df3[column].str.replace(r"\\\\n",r" ",regex=True)

# %%
df3['City  Location'].sort_values().unique()
# Out:
# array(['agra', 'ahemadabad', 'ahemdabad', 'ahmedabad', 'amritsar',
#        'andheri', 'bangalore', 'bangalore / palo alto',
#        'bangalore / san mateo', 'bangalore / sfo', 'bangalore / usa',
#        'bangalore/ bangkok', 'belgaum', 'bengaluru',
#        'bengaluru and gurugram', 'bhopal', 'bhubaneswar', 'bhubneswar',
#        'boston', 'burnsville', 'california', 'chandigarh', 'chembur',
#        'chennai', 'chennai/ singapore', 'coimbatore',
#        'dallas / hyderabad', 'delhi', 'delhi & cambridge', 'faridabad',
#        'gaya', 'goa', 'goa/hyderabad', 'gurgaon', 'gurgaon / sfo',
#        'gurugram', 'gwalior', 'haryana', 'hubli', 'hyderabad',
#        'hyderabad/usa', 'india', 'india / us', 'india/singapore',
#        'india/us', 'indore', 'jaipur', 'jodhpur', 'kanpur', 'karnataka',
#        'karur', 'kerala', 'kochi', 'kolkata', 'kolkatta', 'kormangala',
#        'kozhikode', 'london', 'lucknow', 'menlo park', 'missourie',
#        'mumbai', 'mumbai / global', 'mumbai / ny', 'mumbai / uk',
#        'mumbai/bengaluru', 'nagpur', 'nairobi', 'new delhi',
#        'new delhi / california', 'new delhi / us', 'new delhi/ houston',
#        'new york', 'new york, bengaluru', 'new york/ india', 'noida',
#        'noida / singapore', 'nw delhi', 'palo alto', 'panaji', 'pune',
#        'pune / dubai', 'pune / singapore', 'pune / us', 'pune/seattle',
#        'rourkela', 'san francisco', 'san jose,', 'santa monica',
#        'seattle / bangalore', 'sfo / bangalore', 'siliguri', 'singapore',
#        'srinagar', 'surat', 'taramani', 'trivandrum', 'tulangan',
#        'udaipur', 'udupi', 'us', 'us/india', 'usa', 'usa/india',
#        'uttar pradesh', 'vadodara', 'varanasi', nan], dtype=object)

# %%
df3['City  Location']=df3["City  Location"].replace({
    "bengaluru":"bengalore",
    "ahemedabad":"ahmedabad",
    "ahmadabad" : "ahmedabad",
    "bhubneswar":"bhubaneswar",
    "kolkatta":"kolkata",
    "nw delhi":"new delhi",
    "delhi":"new delhi"
})

# %%
indian_cities = ['agra', 'ahmedabad', 'amritsar', 'andheri', 'bangalore','bhopal',
       'bhubaneswar', 'chandigarh',
       'chembur', 'chennai', 'coimbatore',
       'hyderabad','faridabad',
       'gaya', 'goa','gurgaon',
       'gurugram', 'gwalior', 'haryana', 'hubli',
       'india', 'indore', 'jaipur', 'jodhpur', 'kanpur', 'karnataka',
       'karur', 'kerala', 'kochi', 'kolkata', 'kormangala', 'kozhikode',
       'lucknow','mumbai',
        'nagpur', 'nairobi','noida',
        'panaji', 'pune','rourkela',
       'siliguri',
       'srinagar', 'surat', 'taramani', 'trivandrum', 'tulangan',
       'udaipur', 'udupi',
       'uttar pradesh', 'vadodara', 'varanasi']

# %% [markdown]
# # Column: 'Investors Name'

# %%
column = 'Investors Name'
print('Number of unique Values',df3[column].nunique())
df3[column] = df3[column].str.lower().str.strip()
print('Number of unique Values after changing to lowercase and trimming',df3[column].nunique())
print("Total number of null values",df3[column].isnull().sum())
print("\n")
df3[column]
# Out:
# Number of unique Values 2412
# Number of unique Values after changing to lowercase and trimming 2385
# Total number of null values 24
# Sr No
# 1                 tiger global management
# 2               susquehanna growth equity
# 3                   sequoia capital india
# 4                          vinod khatumal
# 5                 sprout venture partners
#                       ...
# 3040          asia pacific internet group
# 3041                       karsemven fund
# 3042       exfinity fund, growx ventures.
# 3043                           makemytrip
# 3044    uk based group of angel investors
# Name: Investors Name, Length: 3044, dtype: object

# %%
column = 'Investors Name'
# removed special characters or Unicode characters
df3[column] = df3[column].str.replace(r"\\\\x[a-f0-9]{2}",r"",regex=True)
df3[column] = df3[column].str.replace(r"\\x[a-f0-9]{2}",r"",regex=True)
df3[column] = df3[column].str.replace(r"\\\\n",r" ",regex=True)

# %% [markdown]
# # Column: 'Investment Type'

# %%
column = 'Investment Type'
print('Number of unique Values',df3[column].nunique())
df3[column] = df3[column].str.lower().str.strip()
print('Number of unique Values after changing to lowercase and trimming',df3[column].nunique())
print("Total number of null values",df3[column].isnull().sum())
print("\n")
df3[column]
# Out:
# Number of unique Values 55
# Number of unique Values after changing to lowercase and trimming 50
# Total number of null values 4
# Sr No
# 1       private equity round
# 2                   series c
# 3                   series b
# 4               pre-series a
# 5                 seed round
#                 ...
# 3040          private equity
# 3041          private equity
# 3042          private equity
# 3043          private equity
# 3044            seed funding
# Name: Investment Type, Length: 3044, dtype: object

# %%
column = 'Investment Type'
# removed special characters or Unicode characters
df3[column] = df3[column].str.replace(r"\\\\x[a-f0-9]{2}",r"",regex=True)
df3[column] = df3[column].str.replace(r"\\x[a-f0-9]{2}",r"",regex=True)
df3[column] = df3[column].str.replace(r"\\\\n",r" ",regex=True)

# %%
df3["Investment Type"].value_counts().sort_index()
# Out:
# angel                             1
# angel / seed funding              8
# angel funding                     1
# angel round                       1
# bridge round                      1
# corporate round                   2
# crowd funding                     2
# debt                              1
# debt and preference capital       1
# debt funding                     25
# debt-funding                      1
# equity                            2
# equity based funding              1
# funding round                     1
# inhouse funding                   1
# maiden round                      1
# mezzanine                         1
# pre series a                      1
# pre-series a                      8
# private                           1
# private equity                 1357
# private equity round              4
# private funding                   1
# privateequity                     1
# seed                              4
# seed / angel funding             47
# seed / angle funding              3
# seed funding                   1386
# seed funding round                1
# seed round                        7
# seed/ angel funding              60
# seed/angel funding               23
# series a                         24
# series b                         20
# series b (extension)              1
# series c                         14
# series d                         12
# series e                          2
# series f                          2
# series g                          1
# series h                          1
# series j                          1
# single venture                    1
# structured debt                   1
# term loan                         1
# venture                           1
# venture - series unknown          1
# venture round                     2
# Name: Investment Type, dtype: int64

# %%
df3["Investment Type"] = df3["Investment Type"].replace(r"\s*/\s*",r"/",regex=True)

df3["Investment Type"] = df3["Investment Type"].replace({
    "angel" : "angel funding",
    "seed/angle funding":'seed/angel funding',
    "angel round": "angel funding",
    "debt" : "debt funding",
    "debt and preference capital":"debt funding",
    "debt-funding": "debt funding",
    "pre series a":"pre-series a",
    "private":"private equity",
    "privateequity":"private equity",
    "private equity round":"private equity",
    "private funding":"private equity",
    "seed":"seed funding",
    "seed round":"seed funding",
    "seed funding round":"seed funding",
    "venture - series unknown" :"venture round",
    "venture":'venture round',
})

# %%
# df3["Investment Type"].value_counts().sort_index()

#dropping null values
df3.dropna(subset=["Investors Name","Investment Type","City  Location"],how="any", inplace = True)

# %% [markdown]
# # Column: 'Amount in USD'

# %%
df3["Amount in USD"].dtype
# Out:
# dtype('O')

# %%
column = 'Amount in USD'
print('Number of unique Values',df3[column].nunique())
df3[column] = df3[column].str.lower().str.strip()
print('Number of unique Values after changing to lowercase and trimming',df3[column].nunique())
print("Total number of null values",df3[column].isnull().sum())
print("\n")
df3[column].sort_values(na_position="first")
# Out:
# Number of unique Values 451
# Number of unique Values after changing to lowercase and trimming 450
# Total number of null values 910
# Sr No
# 145            NaN
# 156            NaN
# 158            NaN
# 166            NaN
# 190            NaN
#           ...
# 90     undisclosed
# 59     undisclosed
# 21     undisclosed
# 140    undisclosed
# 35         unknown
# Name: Amount in USD, Length: 2836, dtype: object

# %%
column = 'Amount in USD'
# removed special characters or Unicode characters
df3[column] = df3[column].str.replace(r"\\\\x[a-f0-9]{2}",r"",regex=True)
df3[column] = df3[column].str.replace(r"\\x[a-f0-9]{2}",r"",regex=True)
df3[column] = df3[column].str.replace(r"\\\\n",r" ",regex=True)

# %%
# before parsing to number we have to check any string are there or not
df3[df3["Amount in USD"].str.contains('[a-zA-Z_]',na=False)]
# Out:
#             Date     Startup Name                       Industry Vertical  \
# Sr No
# 21    2019-11-17     burger singh                       food and beverage
# 35    2019-10-21  the man company                          consumer goods
# 59    2019-08-19   mishry reviews                                services
# 90    2019-05-06              ola                               transport
# 92    2019-05-05       styledotme                              e-commerce
# 113   2019-02-01           fleetx                                      ai
# 140   2018-11-22         skillbox                          social network
# 2605  2015-07-09         shopsity             fashion info aggregator app
# 2606  2015-07-09         notesgen          online study notes marketplace
# 2612  2015-07-13        satvacart                 online grocery delivery
# 2614  2015-07-14           zenify  residential rental management platform
#
#                                   SubVertical City  Location  \
# Sr No
# 21                        indian burger brand        gurgaon
# 35                        beauty and grooming        gurgaon
# 59                             product review        gurgaon
# 90                                       cabs      bengalore
# 92                       fashion and shopping      new delhi
# 113                                 logistics        gurgaon
# 140                                       art       gurugram
# 2605                                  Unknown        gurgaon
# 2606              online notes sharing portal      new delhi
# 2612                           online grocers        gurgaon
# 2614   home rental discovery & booking portal      bangalore
#
#                                           Investors Name  Investment Type  \
# Sr No
# 21                                        rb investments    venture round
# 35                                     ayushmann khurana  corporate round
# 59                                           vir sanghvi         series a
# 90                                             tata sons         series a
# 92     indian angel network and other angel investors...     bridge round
# 113           india quotient and letsventures angel fund     pre-series a
# 140                                 individual investors     seed funding
# 2605                     sandeep aggarwal, teruhide sato     seed funding
# 2606        rajeev saraf, arvind jha, r. satya narayanan     seed funding
# 2612                                    palaash ventures     seed funding
# 2614                                          atul jalan     seed funding
#
#       Amount in USD
# Sr No
# 21      undisclosed
# 35          unknown
# 59      undisclosed
# 90      undisclosed
# 92      undisclosed
# 113     undisclosed
# 140     undisclosed
# 2605            n/a
# 2606            n/a
# 2612            n/a
# 2614            n/a

# %%
#remove string values
df3["Amount in USD"] = df3["Amount in USD"].replace({
    "undisclosed":np.nan,
    "n/a":np.nan,
    "unknown":np.nan
})

#remove unwanted characters
df3["Amount in USD"] = df3["Amount in USD"].str.replace("[^0-9]","")
# Out:
# <ipython-input-111-a39ed67c767a>:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df3["Amount in USD"] = df3["Amount in USD"].str.replace("[^0-9]","")

# %%
# converting string to float
df3["Amount in USD"] = df3["Amount in USD"].astype(np.float64)

# %%
pd.options.display.float_format = '{:.2f}'.format
df3.describe()
# Out:
#        Amount in USD
# count        1915.00
# mean     19601126.13
# std     129696572.40
# min         18000.00
# 25%        500000.00
# 50%       1800000.00
# 75%       8024197.00
# max    3900000000.00

# %%
df4 = df3.copy()

q3 = df4["Amount in USD"].quantile(.75)

df4 = df4[~(df4["Amount in USD"]>=q3)]

print(df4.shape)
plt.figure(figsize=(8,2))
plt.subplot(1,2,1)
plt.title("with outliers")
sns.boxplot(x ="Amount in USD", data=df3)
plt.subplot(1,2,2)
sns.boxplot(x ="Amount in USD", data=df4)
plt.title("reduced outliers")

sns.displot(x ="Amount in USD", data=df4 , kde = True)
plt.show()
# Out:
# (2357, 8)

# %%
# % of null values
df4.isnull().sum()/len(df3)*100
# Out:
# Date                 0.00
# Startup Name         0.00
# Industry Vertical    0.00
# SubVertical          0.00
# City  Location       0.00
# Investors Name       0.00
# Investment Type      0.00
# Amount in USD       32.48
# dtype: float64

# %%
df4.groupby('Investment Type').agg({"Amount in USD":["min",'median',"max","mean","std","count"]})

# %%
# Na values are filled with median values by grouping based on Investment type
df4["Amount in USD"] = df4.groupby('Investment Type',group_keys=False)['Amount in USD'].apply(lambda x: x.fillna(x.median()))
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)

# %%
df4['Amount in USD'].isnull().sum()
# Out:
# 2

# %%
df4.dropna(inplace=True)

#final Dataset after cleaning and manipulating
df4
# Out:
#             Date     Startup Name           Industry Vertical  \
# Sr No
# 4     2020-01-02     wealthbucket                     fintech
# 5     2020-01-02           fashor         fashion and apparel
# 8     2019-12-12           ecozen                  technology
# 15    2019-12-14            trell                       video
# 19    2019-11-14          misters         health and wellness
# ...          ...              ...                         ...
# 2869  2015-04-29           tracxn  startup analytics platform
# 2870  2015-04-29             dazo    mobile food ordering app
# 2871  2015-04-29         tradelab  financial markets software
# 2872  2015-04-29           piqube   hiring analytics platform
# 2873  2015-04-29  travel triangle   online travel marketplace
#
#                                              SubVertical City  Location  \
# Sr No
# 4                                      online investment      new delhi
# 5                            embroiled clothes for women         mumbai
# 8                                               agritech           pune
# 15                         experience discovery platform      bengalore
# 19                       men's health and wellness brand        gurgaon
# ...                                                  ...            ...
# 2869   indian startup ecosystem trends analyzer & fun...      bangalore
# 2870                                             Unknown      bangalore
# 2871                                             Unknown      bangalore
# 2872                                             Unknown        chennai
# 2873                     online travel agent marketplace          noida
#
#                                           Investors Name Investment Type  \
# Sr No
# 4                                         vinod khatumal    pre-series a
# 5                                sprout venture partners    seed funding
# 8                            sathguru catalyzer advisors        series a
# 15                                   ruizheng investment    seed funding
# 19                         sauce.vc, rainforest ventures        series b
# ...                                                  ...             ...
# 2869                                       saif partners  private equity
# 2870   sumit jain, aprameya radhakrishna, alok goel, ...    seed funding
# 2871                                          rainmatter    seed funding
# 2872                                         the hr fund    seed funding
# 2873            bessemer venture partners, saif partners  private equity
#
#        Amount in USD
# Sr No
# 4         3000000.00
# 5         1800000.00
# 8         6000000.00
# 15        2000000.00
# 19         486000.00
# ...              ...
# 2869      3500000.00
# 2870       350000.00
# 2871       400000.00
# 2872       500000.00
# 2873      8000000.00
#
# [2355 rows x 8 columns]

# %%
pd.options.display.float_format = '{:.2f}'.format
df4.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ba13dcfda4a1> in <cell line: 1>()
# ----> 1 pd.options.display.float_format = '{:.2f}'.format
#       2 df4.describe()
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ---

# %% [markdown]
# **Problem Statement :**
#
# Check the trend of investments over the years. To check the trend, find -
# Total number of fundings done in each year.
# Plot a line graph between year and number of fundings. Take year on x-axis and number of fundings on y-axis.
# Print year-wise total number of fundings also. Print years in ascending order.
#
# **Note :**
# There is some error in the 'Date' feature. Make sure to handle that.

# %%
df4["Year"] = df4['Date'].dt.year
df_year_vs_funding = df4.groupby("Year")["Startup Name"].count().reset_index().rename(columns ={"Startup Name":"Total Counts"})
display(df_year_vs_funding)

sns.set_theme()
sns.lineplot(data=df_year_vs_funding, x = 'Year',y="Total Counts")
plt.show()
# Out:
#    Year  Total Counts
# 0  2015           627
# 1  2016           895
# 2  2017           579
# 3  2018           206
# 4  2019            46
# 5  2020             2

# %% [markdown]
# **Problem Statement :**
#
# Find out which cities are generally chosen for starting a startup.
# Find top 10 Indian cities which have most number of startups ?
# Plot a pie chart and visualise it.
# Print the city name and number of startups in that city also.
#
# **Note :**
# Take city name "Delhi" as "New Delhi".
# Check the case-sensitiveness of cities also. That means - at some place, instead of "Bangalore", "bangalore" is given. Take city name as "Bangalore".
# For few startups multiple locations are given, one Indian and one Foreign. Count those startups in Indian startup also. Indian city name is first.
# Print the city in descending order with respect to the number of startups.

# %%
df5 = df4[df4["City  Location"].str.contains("|".join(indian_cities))].sort_values('City  Location').copy()
df5["Indian City"]= df5["City  Location"].replace(r"\s*/\s*",r"/",regex = True)
df5["Indian City"]= df5["Indian City"].replace(r"("+"|".join(indian_cities)+")/\w+",r"\1",regex = True)
df5["Indian City"]= df5["Indian City"].replace(r"\w+/("+"|".join(indian_cities)+")",r"\1",regex = True)
# df5["Indian City"].unique()

df_city_vs_count = df5.groupby("Indian City")["Startup Name"].count().nlargest(10).reset_index().rename(columns={"Startup Name":"Count"})

display(df_city_vs_count.sort_values("Count",ascending = False))

plt.pie(x=df_city_vs_count["Count"],labels=df_city_vs_count["Indian City"],autopct=lambda x: '{:.0f}'.format(np.round(x/100*df_city_vs_count["Count"].sum())))
plt.show()
# Out:
#   Indian City  Count
# 0   bangalore    600
# 1      mumbai    465
# 2     gurgaon    225
# 3        pune     94
# 4   hyderabad     88
# 5       noida     83
# 6     chennai     77
# 7    gurugram     34
# 8   ahmedabad     33
# 9      jaipur     27

# %% [markdown]
# **Problem Statement :**
#
# Find out if cities play any role in receiving funding.
# Find top 10 Indian cities with most amount of fundings received. Find out percentage of funding each city has got (among top 10 Indian cities only).
# Print the city and percentage with 2 decimal place after rounding off.
#
# **Note:**
# Take city name "Delhi" as "New Delhi".
# Check the case-sensitiveness of cities also. That means - at some place, instead of "Bangalore", "bangalore" is given. Take city name as "Bangalore".
# For few startups multiple locations are given, one Indian and one Foreign. Count those startups in Indian startup also. Indian city name is first.
# Print the city in descending order with respect to the percentage of funding.

# %%
df_city_vs_TotalAmount = df5.groupby("Indian City")["Amount in USD"].sum().nlargest(10).reset_index().rename(columns={"Amount in USD":"Total Amount"})

display(df_city_vs_TotalAmount.sort_values("Total Amount",ascending = False))

plt.pie(x=df_city_vs_TotalAmount["Total Amount"],pctdistance=.8 ,labels=df_city_vs_TotalAmount["Indian City"],autopct=lambda x: '{:.2f}'.format(np.round(x, decimals=2)))
plt.show()
# Out:
#   Indian City  Total Amount
# 0   bangalore  980912410.50
# 1      mumbai  766533315.00
# 2     gurgaon  311107800.00
# 3     chennai  146018000.00
# 4        pune  142008000.00
# 5   hyderabad  124310230.00
# 6       noida  113584000.00
# 7    gurugram   71188523.00
# 8   ahmedabad   40278000.00
# 9      jaipur   32285000.00

# %% [markdown]
# **Problem Statement :**
#
# There are 4 different type of investments. Find out percentage of amount funded for each investment type.
# Plot a pie chart to visualise.
# Print the investment type and percentage of amount funded with 2 decimal places after rounding off.
#
# **Note :**
# Correct spelling of investment types are - "Private Equity", "Seed Funding", "Debt Funding", and "Crowd Funding". Keep an eye for any spelling mistake. You can find this by printing unique values from this column.
# Print the investment type in descending order with respect to the percentage of the amount funded.

# %%
df6 = df5.copy()
# print(df6["Investment Type"].unique())
df6["Investment Type 2"] = df6["Investment Type"].apply(lambda x: "seed funding" if "seed" in x else x )
df6.loc[df6[~df6["Investment Type 2"].isin(["private equity","seed funding","debt funding","crowd funding"])].index,"Investment Type 2"]= "Other"
# df6[df6["Investment Type 2"]=="Other"]
df6 = df6[["Investment Type 2","Amount in USD"]].groupby("Investment Type 2").sum()
display(df6)
plt.pie(data=df6,x="Amount in USD", labels= df6.index, autopct = lambda x: '{:.2f}'.format(round(x,2)))
plt.show()
# Out:
#                    Amount in USD
# Investment Type 2
# Other                71027702.50
# debt funding         60721909.00
# private equity     2242860665.00
# seed funding        492160872.00

# %% [markdown]
# **Problem Statement :**
#
# Which type of companies got more easily funding. To answer this question, find -
# Top 5 industries and percentage of the total amount funded to that industry. (among top 5 only)
# Print the industry name and percentage of the amount funded with 2 decimal place after rounding off.
#
# **Note :**
# Ecommerce is the right word in IndustryVertical, so correct it.
# Print the industry in descending order with respect to the percentage of the amount funded.

# %%
df7 = df5.groupby("Industry Vertical").agg({"Amount in USD":"sum"}).nlargest(5,columns='Amount in USD')

plt.pie(data=df7,x = 'Amount in USD',labels=df7.index, autopct = lambda x : "{:.2f}".format(round(x,2)))
plt.show()

# %% [markdown]
# **Problem Statement :**
#
# Find top 5 startups with most amount of total funding.
# Print the startup name in descending order with respect to amount of funding.
#
# **Note:**
# Ola, Flipkart, Oyo, Paytm are important startups, so correct their names. There are many errors in startup names, ignore correcting all, just handle important ones.

# %%
df8 = df5.groupby("Startup Name").agg({"Amount in USD":"sum"}).nlargest(5,columns='Amount in USD')
display(df8)

plt.pie(data=df8,x = 'Amount in USD',labels=df8.index, autopct = lambda x : "{:.2f}".format(round(x,2)))
plt.show()
# Out:
#               Amount in USD
# Startup Name
# toppr           18620820.00
# indus os        17750000.00
# lendingkart     17150000.00
# magicpin        14600000.00
# aye finance     14240000.00

# %% [markdown]
# **Problem Statement :**
#
# Find the top 5 startups who received the most number of funding rounds. That means, startups which got fundings maximum number of times.
# Print the startup name in descending order with respect to the number of funding round as integer value.
#
# **Note:**
# Ola, Flipkart, Oyo, Paytm are important startups, so correct their names. There are many errors in startup names, ignore correcting all, just handle important ones.

# %%
df9 = df5.groupby("Startup Name").agg({"Amount in USD":"count"}).nlargest(5,columns='Amount in USD')
display(df9)

plt.pie(data=df9,x = 'Amount in USD',labels=df9.index, autopct = lambda x : "{:.2f}".format(round(x,2)))
plt.show()
# Out:
#               Amount in USD
# Startup Name
# medinfi                   6
# holachef                  5
# toppr                     5
# faircent                  4
# fynd                      4

# %% [markdown]
# # Some Insights:

# %% [markdown]
# * Consumer Internet Industrial vertical based startup are most funded in
#
# * Banglore and Mumbai based startup are funded more as per the data
#
# * More money is flowing to start as private equity.
#
# * The Number of Funding to startup is in descresing trend from 2015 to 2020.
